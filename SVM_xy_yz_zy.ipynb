# %% [markdown]
# <a href="https://colab.research.google.com/github/pawan070bct27/CNN_lung_dataset/blob/main/SVM_xy_yz_zy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing necessary libraries

# %%
from sklearn import svm, metrics
from sklearn.preprocessing import StandardScaler
from keras.utils import np_utils
from sklearn.metrics import roc_curve, roc_auc_score, f1_score, accuracy_score, precision_score, recall_score
from collections import deque
from sklearn.model_selection import train_test_split,  GridSearchCV
import matplotlib.pyplot as plt
import time
import pandas as pd
import numpy as np
import tensorflow as tf
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
data_xy = np.load('train_xy.npy')
label_xy = np.load('train_label_xy.npy')

data_yz = np.load('train_yz.npy')
label_yz = np.load('train_label_yz.npy')

data_xz = np.load('train_xz.npy')
label_xz = np.load('train_label_xz.npy')

# %%
sc = StandardScaler()
sc.fit(data_xy)
data_xy_std = sc.transform(data_xy)
sc.fit(data_xz)
data_xz_std = sc.transform(data_xz)
sc.fit(data_yz)
data_yz_std = sc.transform(data_yz)
#X_test_std = sc.transform(X_test)

# %%
#Making a list of dictionaries
datasets = [
{
    'name': 'XY',
    'data': data_xy_std,
    'label': label_xy
},
{
    'name': 'YZ',
    'data': data_yz_std,
    'label': label_yz
},
{
    'name': 'XZ',
    'data': data_xz_std,
    'label': label_xz
  
}
]

# %%
#defining a function for splitting datasets
def split_datasets():
  new_data = m['data'].reshape(167,6,3136)
  new_label = m['label'].reshape(167,6,1)
  X_train, X_test, y_train, y_test = train_test_split(new_data, new_label, test_size=0.3, random_state=101, shuffle = True)

  X_train = X_train.reshape(X_train.shape[0]*6, 3136)
  y_train = y_train.reshape(y_train.shape[0]*6,)

  X_test = X_test.reshape(X_test.shape[0]*6, 3136)
  y_test = y_test.reshape(y_test.shape[0]*6,)
  return X_train, X_test, y_train, y_test

# %%
# Below for loop iterates through your dataset list
list_epoch_accuracy =  []
list_epoch_loss =  [] 
list_epoch_val_accuracy =  []
list_epoch_val_loss =  []
_specificity_ = []
_sensitivity_ = []
_auc_   = []
_f1score_ = []
_accuracy_ = []



for i in range(10):
  for m in datasets:
  # Define per-fold score containers
      acc_per_fold = []
      loss_per_fold = []
      X_train, X_test, y_train, y_test = split_datasets()
      # Merge inputs and targets
      inputs = np.concatenate((X_train, X_test), axis=0)
      targets = np.concatenate((y_train, y_test), axis=0)

      # Define the K-fold Cross Validator
      from sklearn.model_selection import KFold
      kfold = KFold(n_splits= 3, shuffle=True)

      # K-fold Cross Validation model evaluation
      fold_no = 1
      for train, test in kfold.split(inputs, targets):
        
        # Generate a print
        print('------------------------------------------------------------------------')
        print(f'Training for fold {fold_no} ...')
      
        #Create a svm Classifier
        model = svm.SVC(kernel='linear') # Linear Kernel

        #Train the model using the training sets
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        # Generate generalization metrics
        scores = metrics.accuracy_score(y_test, y_pred)
        print(f'Score for fold {fold_no}: Accuracy of {scores*100}%')
        acc_per_fold.append(scores * 100)
        # Increase fold numberå
        fold_no = fold_no + 1
      # == Provide average scores ==
      print('------------------------------------------------------------------------')
      print('Score per fold')
      for i in range(0, len(acc_per_fold)):
        print('------------------------------------------------------------------------')
        print(f'> Fold {i+1} - - Accuracy: {acc_per_fold[i]}%')
      print('------------------------------------------------------------------------')
      print('Average scores for all folds:')
      print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
      print('------------------------------------------------------------------------')
      y_pred=model.predict(X_test)
# Compute False postive rate, and True positive rate
      fpr, tpr, thresholds = roc_curve( y_test, y_pred)
  #Compute precision   
      _specificity= precision_score(y_test, y_pred)
      _specificity_.append(_specificity)
  #Compute recall
      _sensitivity= precision_score(y_test, y_pred)
      _sensitivity_.append(_sensitivity)
  # Calculate Area under the curve to display on the plot
      _auc = roc_auc_score( y_test, y_pred)
      _auc_.append(_auc)
  #accuracy
      _accuracy = accuracy_score( y_test, y_pred)
      _accuracy_.append(_accuracy)
  # F1 -score
      _fscore1 = f1_score( y_test, y_pred)
      _f1score_.append(_fscore1)
  # Now, plot the computed values
      plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (m['name'], _auc))
  # Custom settings for the plot 
  plt.plot([0, 1], [0, 1])
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('Specificity(False Positive Rate)')
  plt.ylabel('Sensitivity(True Positive Rate)')
  plt.title('Receiver Operating Characteristic')
  plt.legend(loc="lower right")
  plt.show() 
    # Display
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 63.39869281045751%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 63.39869281045751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 63.39869281045751 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 55.88235294117647%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 55.88235294117647%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 55.88235294117647 (+- 0.0)
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Score for fold 1: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Score for fold 2: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Score for fold 3: Accuracy of 62.745098039215684%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 2 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# > Fold 3 - - Accuracy: 62.745098039215684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 62.745098039215684 (+- 0.0)
# ------------------------------------------------------------------------

# %%
fig, axs= plt.subplots(1,5,figsize=(13,7), sharey= True)
red_square = dict(markerfacecolor='r', marker='s')
axs[0].set_title('Sensitivity for 10 trials')
axs[0].boxplot(_sensitivity_, flierprops=red_square, whis=0.75)

axs[1].set_title('Specificity for 10 trials')
axs[1].boxplot(_specificity_, flierprops=red_square, whis=0.75)

axs[2].set_title('Accuracy for 10 trials')
axs[2].boxplot(_accuracy_, flierprops=red_square, whis=0.75)

axs[3].set_title('AUC for 10 trials')
axs[3].boxplot(_auc_, flierprops=red_square, whis=0.75)

axs[4].set_title('F1 score for 10 trials')
axs[4].boxplot(_f1score_, flierprops=red_square, whis=0.75)
fig.subplots_adjust(left=0.06, right=1, bottom=1, top=2,
                      hspace=0.5, wspace=0.01)

# %%
#Creating a grouped bar plot
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


barWidth = 0.25
labels = ['Specificity', 'Sensitivity', 'AUC', 'F1-score', 'Accuracy']
cnn_means = [_specificity_[0], _sensitivity_[0], _auc_[0], _f1score_[0], _accuracy_[0]]
cnn1_means = [_specificity_[1], _sensitivity_[1], _auc_[1], _f1score_[1], _accuracy_[1]]
cnn2_means = [_specificity_[2], _sensitivity_[2], _auc_[2], _f1score_[2], _accuracy_[2]]



x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
# Set position of bar on X axis
r1 = x
r2 = [p + barWidth for p in r1]
r3 = [p + barWidth for p in r2]
fig, ax = plt.subplots(figsize=(12,10))
rects1 = ax.bar(r1, (cnn_means), width, label='XY')
rects2 = ax.bar(r2, (cnn1_means), width, label='XZ')
rects3 = ax.bar(r3, (cnn2_means), width, label='YZ')



# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Performance Scores', fontweight='bold', fontsize = 18)
ax.set_xticks(x)
ax.set_xticklabels(labels, fontweight='bold', fontsize = 16, horizontalalignment = 'left')
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.0%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)


fig.tight_layout()

plt.show()
